# %%
import numpy as np
import yfinance as yf 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df= yf.download("NVDA","2018-01-01","2023-01-01")
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
df.describe()
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker         NVDA         NVDA         NVDA         NVDA          NVDA
# count   1259.000000  1259.000000  1259.000000  1259.000000  1.259000e+03
# mean      11.592491    11.818313    11.353762    11.593814  4.775071e+08
# std        7.289118     7.463646     7.110763     7.301668  2.241041e+08
# min        3.151139     3.223049     3.086172     3.136509  9.788400e+07
# 25%        5.560718     5.666117     5.423761     5.564427  3.186180e+08
# 50%        9.581335     9.706182     9.547444     9.607999  4.409200e+08
# 75%       16.117621    16.420341    15.780541    16.061889  5.900880e+08
# max       33.313438    34.582059    31.975950    33.454176  2.511528e+09

# %%
multiple_df.describe()
# Out:
# Price         Close                                   High               \
# Ticker          CAT         NVDA          PEP          CAT         NVDA
# count   1276.000000  1276.000000  1276.000000  1276.000000  1276.000000
# mean     177.002873    18.246540   137.719045   178.981897    18.566533
# std       51.675186    13.158568    24.021380    52.149226    13.359755
# min       82.576218     3.173704    89.480812    84.760853     3.351495
# 25%      123.387648     7.065407   116.757744   124.579442     7.104139
# 50%      183.828552    14.809671   136.100555   185.960041    15.090594
# 75%      213.153931    23.611587   159.329517   215.657778    24.189042
# max      296.307312    61.593864   184.349792   298.809633    62.825404
#
# Price                        Low                                   Open  \
# Ticker          PEP          CAT         NVDA          PEP          CAT
# count   1276.000000  1276.000000  1276.000000  1276.000000  1276.000000
# ...

# %%
start_date ="2019-01-01"
end_date = "2024-01-29"

# %%
multiple_df= yf.download(["NVDA","PEP","CAT"],start=start_date,end=end_date)
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
multiple_df.head()
# Out:
# Price            Close                             High                       \
# Ticker             CAT      NVDA        PEP         CAT      NVDA        PEP
# Date
# 2019-01-02  109.718452  3.377779  91.114990  111.020697  3.433819  91.731982
# 2019-01-03  105.490486  3.173704  90.264549  108.954455  3.351495  91.840385
# 2019-01-04  111.255096  3.377035  92.115540  111.637090  3.415222  92.215589
# 2019-01-07  111.324539  3.555818  91.323456  112.513932  3.592764  92.032164
# 2019-01-08  112.661530  3.467294  92.198914  114.163448  3.639630  92.382345
#
# Price              Low                             Open                       \
# Ticker             CAT      NVDA        PEP         CAT      NVDA        PEP
# Date
# 2019-01-02  106.784063  3.224785  90.239530  107.678270  3.239415  91.006602
# 2019-01-03  104.561552  3.166266  90.089457  108.789502  3.317524  90.806505
# 2019-01-04  107.391773  3.216106  90.247877  107.799811  3.246853  91.331788
# ...

# %%
import matplotlib.pyplot as plt

# %%
df.describe()
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker         NVDA         NVDA         NVDA         NVDA          NVDA
# count   1259.000000  1259.000000  1259.000000  1259.000000  1.259000e+03
# mean      11.592491    11.818313    11.353762    11.593814  4.775071e+08
# std        7.289118     7.463646     7.110763     7.301668  2.241041e+08
# min        3.151139     3.223049     3.086172     3.136509  9.788400e+07
# 25%        5.560718     5.666117     5.423761     5.564427  3.186180e+08
# 50%        9.581335     9.706182     9.547444     9.607999  4.409200e+08
# 75%       16.117621    16.420341    15.780541    16.061889  5.900880e+08
# max       33.313438    34.582059    31.975950    33.454176  2.511528e+09

# %%
adj_close_price = multiple_df['Close']

# %%
adj_close_price.plot(grid=True , linewidth=1,figsize=(14,9))
# Out:
# <Axes: xlabel='Date'>
